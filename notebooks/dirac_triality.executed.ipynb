# %% [markdown]
# # Real $Cl(4,4)$, split octonions, and triality
#
# This generated SolveIt-style notebook checks the exact real algebra and both pure-Rust CVODE studies. It treats historical notebook output as evidence only and uses the repository's independent checkers.

# %%
from pathlib import Path
import csv
import hashlib
import json
import subprocess
import sys

ROOT = Path.cwd().resolve()
assert (ROOT / 'Cargo.toml').is_file()
def sha256(path):
    return hashlib.sha256(path.read_bytes()).hexdigest()
def run_check(script, *arguments):
    process = subprocess.run(
        [sys.executable, str(ROOT / script), *arguments],
        cwd=ROOT, text=True, capture_output=True, check=False
    )
    print(process.stdout.strip())
    assert process.returncode == 0, process.stderr
    return process.stdout
EXPECTED_HASHES = {'cl44': '0660e436fdcf90ed0f0481c9a828e92659987f5820084ccbf5e1dfc96866cc54', 'split': '25044ea194c1e18e40341da1f0098b80bfeb9f4bcb6e7665a32d03f55ac360ca', 'triality': '5985f5c0fdd6656c3c9f572ef1a5d06eee21aabe44cc9bf33747bb79b5e181dd', 'transport': '61b8fe5a8a72e48d40d40d6850a6c559e2dd06ccfa9de97982590d35a82044fb', 'cosmology': '8f1e45a37c14cc10c7c6b6469ceca7c65e7b9ffc08b3c9dd5bfc518065c590db'}

# %% [markdown]
# ## Independent exact-algebra checks
#
# The checks below use standard-library integer and rational arithmetic; they do not trust stored Wolfram results.

# %%
run_check('scripts/check_cl44_fixture.py')
run_check('scripts/check_split_octonion_fixture.py')
run_check('scripts/check_triality44_fixture.py')
# Out:
# check_schemaVersion=true
# check_packageHash=true
# check_signature=true
# check_generatorCount=true
# check_generatorDimensions=true
# check_integerEntries=true
# check_metric=true
# check_cliffordRelations=true
# check_volumeElement=true
# check_volumeSquare=true
# check_volumeOddAnticommutation=true
# check_projectorMatrices=true
# check_projectorIdentities=true
# check_halfSpinIndices=true
# check_oddExchangesHalfSpin=true
# check_spinPreservesHalfSpin=true
# check_spinVectorRelations=true
# check_spinLieRelations=true
# check_fullAlgebraRank=true
# check_evenAlgebraRank=true
# check_halfSpinActionRanks=true
# check_plusSpinCommutant=true
# check_minusSpinCommutant=true
# check_halfSpinInequivalence=true
# measurement_fullAlgebraRankModuloPrime=256
# measurement_evenAlgebraRankModuloPrime=128
# measurement_plusEvenActionRankModuloPrime=64
# measurement_minusEvenActionRankModuloPrime=64
# measurement_plusSpinCommutantDimensionModuloPrime=1
# measurement_minusSpinCommutantDimensionModuloPrime=1
# measurement_halfSpinIntertwinerDimensionModuloPrime=0
# check_count=24
# failed_check_count=0
# check_schemaVersion=true
# check_packageHash=true
# check_signature=true
# check_tensorDimensions=true
# check_integerStructureConstants=true
# check_metric=true
# check_zornReconstruction=true
# check_unit=true
# check_conjugationReversal=true
# check_quadraticPolarization=true
# check_leftCompositionPolarization=true
# check_rightCompositionPolarization=true
# check_alternativity=true
# check_paraTensor=true
# check_paraTrilinearCyclic=true
# check_ordinaryTensorModeRanks=true
# check_paraTensorModeRanks=true
# measurement_nonzeroOrdinaryStructureConstants=64
# measurement_nonzeroParaStructureConstants=64
# measurement_ordinaryTensorModeRanks=[8, 8, 8]
# measurement_paraTensorModeRanks=[8, 8, 8]
# check_count=17
# failed_check_count=0
# check_schemaVersion=true
# check_packageHashes=true
# check_signature=true
# check_pairLabels=true
# check_coefficientShape=true
# check_canonicalVectorProjection=true
# check_representationReconstruction=true
# check_projectionRanks=true
# check_metricSkew=true
# check_definingRelation=true
# check_lieRelations=true
# check_invariantTrilinear=true
# check_representationCommutants=true
# check_representationInequivalence=true
# check_cyclicOrderThree=true
# check_reflectionOrderTwo=true
# check_s3BraidRelation=true
# check_s3ElementCount=true
# check_cyclicPermutesRepresentations=true
# check_reflectionConjugateSwap=true
# check_octonionCliffordRelations=true
# check_cliffordIntertwiner=true
# check_canonicalHalfSpinMatching=true
# check_wolframChecks=true
# measurement_projectionRanksModuloPrime=[28, 28, 28]
# measurement_representationCommutantDimensionsModuloPrime=[1, 1, 1]
# measurement_representationIntertwinerDimensionsModuloPrime=[0, 0, 0]
# measurement_s3ElementCount=6
# measurement_cliffordIntertwinerRankModuloPrime=16
# measurement_canonicalHalfSpinMatchingDimensionsModuloPrime=[[1, 0], [0, 1]]
# check_count=24
# failed_check_count=0
# 'check_schemaVersion=true\ncheck_packageHashes=true\ncheck_signature=true\ncheck_pairLabels=true\ncheck_coefficientShape=true\ncheck_canonicalVectorProjection=true\ncheck_representationReconstruction=true\ncheck_projectionRanks=true\ncheck_metricSkew=true\ncheck_definingRelation=true\ncheck_lieRelations=true\ncheck_invariantTrilinear=true\ncheck_representationCommutants=true\ncheck_representationInequivalence=true\ncheck_cyclicOrderThree=true\ncheck_reflectionOrderTwo=true\ncheck_s3BraidRelation=true\ncheck_s3ElementCount=true\ncheck_cyclicPermutesRepresentations=true\ncheck_reflectionConjugateSwap=true\ncheck_octonionCliffordRelations=true\ncheck_cliffordIntertwiner=true\ncheck_canonicalHalfSpinMatching=true\ncheck_wolframChecks=true\nmeasurement_projectionRanksModuloPrime=[28, 28, 28]\nmeasurement_representationCommutantDimensionsModuloPrime=[1, 1, 1]\nmeasurement_representationIntertwinerDimensionsModuloPrime=[0, 0, 0]\nmeasurement_s3ElementCount=6\nmeasurement_cliffordIntertwinerRankModuloPrime=16\nmeasurement_canonicalHalfSpinMatchingDimensionsModuloPrime=[[1, 0], [0, 1]]\ncheck_count=24\nfailed_check_count=0\n'

# %% [markdown]
# ## CVODE studies
#
# The transport study evolves 24 real states. The cosmology study evolves 18 real states and is compared against analytic background identities.

# %%
run_check('scripts/check_triality_transport.py')
run_check('scripts/check_spinor_cosmology.py')
transport = json.loads((ROOT / 'artifacts/triality-transport/summary.json').read_text())
cosmology = json.loads((ROOT / 'artifacts/spinor-cosmology/summary.json').read_text())
print({'transport_samples': transport['sampleCount'], 'cosmology_samples': cosmology['sampleCount']})
# Out:
# check_filesPresent=true
# check_schemaVersion=true
# check_studyName=true
# check_stateDimension=true
# check_fixtureHashes=true
# check_csvHeader=true
# check_sampleCount=true
# check_finiteValues=true
# check_timeGrid=true
# check_initialInvariants=true
# check_recordedInvariants=true
# check_driftLimit=true
# check_summaryDrift=true
# check_summaryVerdict=true
# check_repeatByteIdentity=true
# measurement_sampleCount=41
# measurement_maximumDrift=[1.2915224445464446e-12, 3.0707658638107205e-12, 2.8042013155982204e-12, 2.9650726318664056e-12]
# measurement_trajectorySha256=ee5ad82ee604f072f04bed8ef20cdd856bb02ba80e16c3973b10c6c43f972b9c
# measurement_summarySha256=61b8fe5a8a72e48d40d40d6850a6c559e2dd06ccfa9de97982590d35a82044fb
# measurement_repeatCompared=False
# check_count=15
# failed_check_count=0
# check_filesPresent=true
# check_schemaVersion=true
# check_studyName=true
# check_stateDimension=true
# check_fixtureHash=true
# check_parameters=true
# check_flatness=true
# check_csvHeader=true
# check_sampleCount=true
# check_finiteValues=true
# check_eFoldGrid=true
# check_presentEpochOnce=true
# check_recordedDerivedValues=true
# check_recordedErrors=true
# check_errorLimits=true
# check_summaryErrors=true
# check_repeatByteIdentity=true
# measurement_sampleCount=1201
# measurement_maximumRelativeErrors=[6.565508926246135e-09, 8.67334933419025e-10, 7.707676290195425e-09, 3.0848480998659325e-11]
# measurement_backgroundSha256=8a6f7ace34949d82d4022a9b5a660733ed018c91b2b931d934aab7793b5585c2
# measurement_summarySha256=8f1e45a37c14cc10c7c6b6469ceca7c65e7b9ffc08b3c9dd5bfc518065c590db
# measurement_repeatCompared=False
# check_count=17
# failed_check_count=0
# {'transport_samples': 41, 'cosmology_samples': 1201}

# %% [markdown]
# ## Dataset inspection
#
# The notebook reads the canonical CSV files directly and checks their endpoint grids and row counts.

# %%
def read_csv(relative_path):
    with (ROOT / relative_path).open(newline='', encoding='utf-8') as stream:
        return list(csv.DictReader(stream))
transport_rows = read_csv('artifacts/triality-transport/trajectory.csv')
cosmology_rows = read_csv('artifacts/spinor-cosmology/background.csv')
assert len(transport_rows) == 41
assert len(cosmology_rows) == 1201
assert float(transport_rows[0]['t']) == 0.0
assert float(transport_rows[-1]['t']) == 4.0
assert float(cosmology_rows[0]['N']) == -4.0
assert float(cosmology_rows[-1]['N']) == 1.0
{'transport_final': transport_rows[-1], 'cosmology_present': cosmology_rows[960]}
# Out:
# {'transport_final': {'t': '4.00000000000000000e+00',
#   'y0': '6.79962460520447953e-01',
#   'y1': '-8.10980789469098906e-01',
#   'y2': '0.00000000000000000e+00',
#   'y3': '0.00000000000000000e+00',
#   'y4': '3.46070021210293954e-01',
#   'y5': '-1.65628809561752938e-02',
#   'y6': '0.00000000000000000e+00',
#   'y7': '0.00000000000000000e+00',
#   'y8': '1.04348207252931235e+00',
#   'y9': '2.57378217951774235e-01',
#   'y10': '0.00000000000000000e+00',
#   'y11': '0.00000000000000000e+00',
#   'y12': '7.08039952839037562e-02',
#   'y13': '-3.87408282068338050e-01',
#   'y14': '0.00000000000000000e+00',
#   'y15': '0.00000000000000000e+00',
#   'y16': '9.49177165339466833e-01',
#   'y17': '5.38338714366538351e-01',
#   'y18': '0.00000000000000000e+00',
#   'y19': '0.00000000000000000e+00',
#   'y20': '-9.08183225954014156e-02',
#   'y21': '4.27197723385596251e-01',
#   'y22': '0.00000000000000000e+00',
#   'y23': '0.00000000000000000e+00',
#   'norm_v': '9.99999999998882894e-01',
#   'norm_plus': '1.00000000000279599e+00',
#   'norm_minus': '1.00000000000280420e+00',
#   'trilinear': '1.00000000000224176e+00'},
#  'cosmology_present': {'N': '0.00000000000000000e+00',
#   'a': '1.00000000000000000e+00',
#   'tau': '0.00000000000000000e+00',
#   'rho': '6.94910000000000028e-01',
#   'psi0': '1.00000000000000000e+00',
#   'psi1': '0.00000000000000000e+00',
#   'psi2': '0.00000000000000000e+00',
#   'psi3': '0.00000000000000000e+00',
#   'psi4': '0.00000000000000000e+00',
#   'psi5': '0.00000000000000000e+00',
#   'psi6': '0.00000000000000000e+00',
#   'psi7': '0.00000000000000000e+00',
#   'psi8': '0.00000000000000000e+00',
#   'psi9': '0.00000000000000000e+00',
#   'psi10': '0.00000000000000000e+00',
#   'psi11': '0.00000000000000000e+00',
#   'psi12': '0.00000000000000000e+00',
#   'psi13': '0.00000000000000000e+00',
#   'psi14': '0.00000000000000000e+00',
#   'psi15': '0.00000000000000000e+00',
#   'S': '1.00000000000000000e+00',
#   'U': '6.94910000000000028e-01',
#   'w': '-8.60999999999999988e-01',
#   'E': '1.00000000000000000e+00',
#   'S_relative_error': '0.00000000000000000e+00',
#   'rho_relative_error': '0.00000000000000000e+00',
#   'potential_relative_error': '0.00000000000000000e+00',
#   'friedmann_relative_error': '0.00000000000000000e+00'}}

# %% [markdown]
# ## Reproducibility report

# %%
actual_hashes = {
    'cl44': sha256(ROOT / 'artifacts/exact/cl44-seed.json'),
    'split': sha256(ROOT / 'artifacts/exact/split-octonion.json'),
    'triality': sha256(ROOT / 'artifacts/exact/triality44.json'),
    'transport': sha256(ROOT / 'artifacts/triality-transport/summary.json'),
    'cosmology': sha256(ROOT / 'artifacts/spinor-cosmology/summary.json'),
}
NOTEBOOK_CHECKS = {
    'input_hashes': actual_hashes == EXPECTED_HASHES,
    'transport_success': transport['verdict'] == 'SUCCESS',
    'transport_dimension': transport['stateDimension'] == 24,
    'cosmology_success': cosmology['verdict'] == 'SUCCESS',
    'cosmology_dimension': cosmology['stateDimension'] == 18,
    'dataset_counts': len(transport_rows) == 41 and len(cosmology_rows) == 1201,
}
assert all(NOTEBOOK_CHECKS.values()), NOTEBOOK_CHECKS
report_path = ROOT / 'artifacts/notebooks/jupyter-report.json'
report_path.parent.mkdir(parents=True, exist_ok=True)
report = {'schemaVersion': 1, 'checks': NOTEBOOK_CHECKS, 'inputSha256': actual_hashes}
report_path.write_text(json.dumps(report, indent=2, sort_keys=True) + '\n', encoding='utf-8')
NOTEBOOK_CHECKS
# Out:
# {'input_hashes': True,
#  'transport_success': True,
#  'transport_dimension': True,
#  'cosmology_success': True,
#  'cosmology_dimension': True,
#  'dataset_counts': True}
